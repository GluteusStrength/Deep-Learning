# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from PIL import Image

# %%
image_path = '/content/drive/MyDrive/Data/3rd_filtering/picture'

label_path = os.listdir(image_path)

label_paths = [os.path.join(image_path,label_path[i]) for i in range(len(label_path))] 

image_jpg = [os.listdir(label_paths[i]) for i in range(len(label_paths))]

image_paths = []
for i in range(len(label_paths)):
    sub_paths = []
    for j in range(len(image_jpg[i])):
        sub_paths.append(os.path.join(label_paths[i], image_jpg[i][j]))
    image_paths.append(sub_paths)

# %%
label = []
img_length = []
for idx in range(len(label_paths)):
    name = label_paths[idx][-5:]
    if name[0] == "/":
        name = name[1:]
    label.append(name)
    img_length.append(len(image_paths[idx]))
plt.figure(figsize = (13, 10))
plt.bar(label, img_length)
ans = 0

for i, v in enumerate(label):
    plt.text(v, img_length[i], img_length[i],                 # 좌표 (x축 = v, y축 = y[0]..y[1], 표시 = y[0]..y[1])
             fontsize = 20, 
             color='blue',
             horizontalalignment='center',  # horizontalalignment (left, center, right)
             verticalalignment='bottom')

for i in range(len(image_paths)):
    ans += len(image_paths[i])
print(ans)
# Out:
# 21864

# %%
image_path = '/content/drive/MyDrive/Data/grouping_data'

label_path = os.listdir(image_path)

label_paths = [os.path.join(image_path,label_path[i]) for i in range(len(label_path))] 

image_jpg = [os.listdir(label_paths[i]) for i in range(len(label_paths))]

image_paths = []
for i in range(len(label_paths)):
    sub_paths = []
    for j in range(len(image_jpg[i])):
        sub_paths.append(os.path.join(label_paths[i], image_jpg[i][j]))
    image_paths.append(sub_paths)

# %%
label = []
img_length = []
for idx in range(len(label_paths)):
    name = label_paths[idx][-5:]
    if name[0] == "/":
        name = name[1:]
    label.append(name)
    img_length.append(len(image_paths[idx]))
plt.figure(figsize = (15, 12))
plt.bar(label, img_length)
# Out:
# <BarContainer object of 20 artists>

# %%
image_path = '/content/drive/MyDrive/Data/split_data/train'

label_path = os.listdir(image_path)

label_paths = [os.path.join(image_path,label_path[i]) for i in range(len(label_path))] 

image_jpg = [os.listdir(label_paths[i]) for i in range(len(label_paths))]

image_paths = []
for i in range(len(label_paths)):
    sub_paths = []
    for j in range(len(image_jpg[i])):
        sub_paths.append(os.path.join(label_paths[i], image_jpg[i][j]))
    image_paths.append(sub_paths)

# %%
label = []
img_length = []
for idx in range(len(label_paths)):
    name = label_paths[idx][-5:]
    if name[0] == "/":
        name = name[1:]
    label.append(name)
    img_length.append(len(image_paths[idx]))
plt.figure(figsize = (15, 12))
plt.bar(label, img_length)
# Out:
# <BarContainer object of 20 artists>

# %%
dic = {'L2_3':1000,
'L2_10': 1293,
'L2_12': 930,
'L2_15': 1106,
'L2_20': 1035,
'L2_21': 1040,
'L2_24':1035,
'L2_25': 1015,
'L2_27': 1050,
'L2_30': 1080,
'L2_33': 1700,
'L2_34': 1065,
'L2_39': 1085,
'L2_40': 968,
'L2_41': 970,
'L2_44': 1096,
'L2_45': 1192,
'L2_46': 1341,
'L2_50': 995,
'L2_52': 920,
}

# %%
x_l = list(dic.keys())

# %%
y_l = list(dic.values())

# %%
plt.figure(figsize = (12, 8))
plt.bar(x_l, y_l)
# Out:
# <BarContainer object of 20 artists>

# %%
'L2_3':1000
'L2_10': 1293
'L2_12': 930
'L2_15': 1106
'L2_20': 1035
'L2_21': 1040
'L2_24':1035
'L2_25': 1015
'L2_27': 1050
'L2_30': 1080
'L2_33': 1700
'L2_34': 1065
'L2_39': 1085
'L2_40': 968
'L2_41': 970
'L2_44': 1096
'L2_45': 1192
'L2_46': 1341
'L2_50': 995
'L2_52': 920
